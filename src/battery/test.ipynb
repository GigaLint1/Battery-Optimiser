# %%
from fetcher import fetch_caiso_prices, fetch_ercot_prices, process_ercot_data

# %%
df = process_ercot_data(r"C:\Users\grego\Documents\Github\Battery Optimiser\data\raw")

# %%
columns = sorted(df['BusName'].unique().tolist())
found = [item for item in columns if "ADICKS" in item]
print(found)
# Out:
# ['ADICKS_138A', 'ADICKS_138N', 'ADICKS_345B', 'ADICKS__138C', 'ADICKS__345D', 'ADICKS__8030', 'CADICKS_804N', 'CADICKS_804O', 'CADICKS_804V']

# %%
# Out:
# Error: Ercot.get_lmp() got an unexpected keyword argument 'market'
# Args: {'self': <gridstatus.ercot.Ercot object at 0x0000025C13626990>, 'market': 'DAY_AHEAD_HOURLY', 'locations': ['HB_HOUSTON'], 'date': Timestamp('2025-01-01 00:00:00-0600', tz='US/Central'), 'end': Timestamp('2025-01-03 00:00:00-0600', tz='US/Central')}
#
# Errors that occurred while getting data:
# [{'date': Timestamp('2025-01-01 00:00:00-0600', tz='US/Central'),
#   'end': Timestamp('2025-01-03 00:00:00-0600', tz='US/Central'),
#   'locations': ['HB_HOUSTON'],
#   'market': 'DAY_AHEAD_HOURLY',
#   'self': <gridstatus.ercot.Ercot object at 0x0000025C13626990>}]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = fetch_ercot_prices("2025-01-01", "2025-01-03")
#       2 print(df.head())
#
# ...
